# %%
# from dask.distributed import Client, progress
import dask.dataframe as dd
import dask
import pandas as pd
import csv
from glob import glob

# %%
# loading in through pandas
df = pd.read_csv("/mnt/research/CMSE495-SS24-ICER/slurm_usage/DID_FINAL_SLURM_OCT_2023.csv", delimiter = "|", nrows = 1e5)
df = df.drop(columns=["Unnamed: 0","Unnamed: 0.1"])
df = df[df["State"] == "COMPLETED"]
df.head(5)
# Out:
#       JobID      User      Group               Submit                Start  \
# 4  59062820  user_188  group_046  2023-05-08T09:58:20  2024-01-01T00:58:57
# 5  59062828  user_188  group_046  2023-05-08T09:58:20  2024-01-01T01:00:49
# 6  59062836  user_188  group_046  2023-05-08T09:58:20  2024-01-01T01:00:49
# 7  59062844  user_188  group_046  2023-05-08T09:58:21  2024-01-01T00:58:57
# 8  59062852  user_188  group_046  2023-05-08T09:58:21  2024-01-01T00:58:57
#
#                    End   Elapsed      State      Account      AssocID  ...  \
# 4  2024-01-01T00:59:06  00:00:09  COMPLETED  account_017  assocID_676  ...
# 5  2024-01-01T01:00:55  00:00:06  COMPLETED  account_017  assocID_676  ...
# 6  2024-01-01T01:00:55  00:00:06  COMPLETED  account_017  assocID_676  ...
# 7  2024-01-01T00:59:06  00:00:09  COMPLETED  account_017  assocID_676  ...
# 8  2024-01-01T00:59:06  00:00:09  COMPLETED  account_017  assocID_676  ...
#
#   CPUTimeRAW ReqCPUS AllocCPUS ReqMem MaxRSS ReqNodes  NNodes  NodeList  \
# 4        360      40        40     8G    NaN        1       1   skl-029
# 5        240      40        40     8G    NaN        1       1   skl-029
# 6        240      40        40     8G    NaN        1       1   skl-030
# 7        360      40        40     8G    NaN        1       1   amr-207
# 8        360      40        40     8G    NaN        1       1   amr-207
#
#                              ReqTRES                          AllocTRES
# 4  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
# 5  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
# 6  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
# 7  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
# 8  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
#
# [5 rows x 26 columns]

# %%
# loading in data
slurm = dd.read_csv("/mnt/research/CMSE495-SS24-ICER/slurm_usage/DID_FINAL_SLURM_OCT_2023.csv",delimiter="|", dtype={'MaxRSS': 'object'})
slurm = slurm.drop(columns=["Unnamed: 0","Unnamed: 0.1"])

# %%
slurm.head()
# Out:
#       JobID      User      Group               Submit                Start  \
# 0  31496544  user_679  group_121  2023-03-21T11:13:45              Unknown
# 1  31497932  user_679  group_121  2023-03-21T11:31:18              Unknown
# 2  31993628  user_105  group_114  2023-03-22T18:19:12              Unknown
# 3  39087660  user_652  group_054  2023-04-04T13:09:10              Unknown
# 4  59062820  user_188  group_046  2023-05-08T09:58:20  2024-01-01T00:58:57
#
#                    End   Elapsed      State      Account      AssocID  ...  \
# 0              Unknown  00:00:00    PENDING  account_017  assocID_489  ...
# 1              Unknown  00:00:00    PENDING  account_017  assocID_489  ...
# 2              Unknown  00:00:00    PENDING  account_017  assocID_661  ...
# 3              Unknown  00:00:00    PENDING  account_017  assocID_557  ...
# 4  2024-01-01T00:59:06  00:00:09  COMPLETED  account_017  assocID_676  ...
#
#   CPUTimeRAW ReqCPUS AllocCPUS  ReqMem MaxRSS ReqNodes  NNodes       NodeList  \
# 0          0      28         0  21000M   <NA>        1       1  None assigned
# 1          0      28         0  21000M   <NA>        1       1  None assigned
# 2          0      12         0    150G   <NA>        1       1  None assigned
# 3          0     640         0     20G   <NA>       10      10  None assigned
# 4        360      40        40      8G   <NA>        1       1        skl-029
#
#                                             ReqTRES  \
# 0  billing=3192,cpu=28,gres/gpu=4,mem=21000M,node=1
# 1  billing=3192,cpu=28,gres/gpu=4,mem=21000M,node=1
# 2   billing=23347,cpu=12,gres/gpu=8,mem=150G,node=1
# 3              billing=3112,cpu=640,mem=20G,node=10
# 4                 billing=1245,cpu=40,mem=8G,node=1
#
#                            AllocTRES
# 0                               <NA>
# 1                               <NA>
# 2                               <NA>
# 3                               <NA>
# 4  billing=1245,cpu=40,mem=8G,node=1
#
# [5 rows x 26 columns]

# %%
slurm = slurm.repartition(partition_size="250 MB").persist()
print(f"Number of records: {len(slurm)}")
# Out:
# Number of records: 6376308

# %%
# HANDLING 0 SEC DATA
# slurm0sec = slurm.loc[slurm.Elapsed == '00:00:00']
# slurm0sec.head()
# slurm0sec.loc[slurm0sec.User == "user_258"].head()
# slurm0sec.to_csv("/mnt/scratch/tairaeli/cmse_dat/slurm0_sec_jobs/part*.csv")

# %%
batch_extern = slurm.loc[slurm.User=="user_258"]

batch = batch_extern[(batch_extern.MaxRSS.notnull()) & (batch_extern.MaxRSS != '0')]

batch = batch.loc[batch.Elapsed != '00:00:00']

bsub = batch.loc[:,["CPUTimeRAW","MaxRSS"]]

# %%
bsub.head()
# Out:
#      CPUTimeRAW    MaxRSS
# 202     1855216   983172K
# 204     4244304     4500K
# 206     1731008  1076136K
# 208     3895008     4540K
# 210     1695376  1051988K

# %%
slurm_clean = slurm.loc[(slurm.Elapsed != '00:00:00') & (slurm.User!="user_258")]
slurm_clean.head()
# Out:
#       JobID      User      Group               Submit                Start  \
# 4  59062820  user_188  group_046  2023-05-08T09:58:20  2024-01-01T00:58:57
# 5  59062828  user_188  group_046  2023-05-08T09:58:20  2024-01-01T01:00:49
# 6  59062836  user_188  group_046  2023-05-08T09:58:20  2024-01-01T01:00:49
# 7  59062844  user_188  group_046  2023-05-08T09:58:21  2024-01-01T00:58:57
# 8  59062852  user_188  group_046  2023-05-08T09:58:21  2024-01-01T00:58:57
#
#                    End   Elapsed      State      Account      AssocID  ...  \
# 4  2024-01-01T00:59:06  00:00:09  COMPLETED  account_017  assocID_676  ...
# 5  2024-01-01T01:00:55  00:00:06  COMPLETED  account_017  assocID_676  ...
# 6  2024-01-01T01:00:55  00:00:06  COMPLETED  account_017  assocID_676  ...
# 7  2024-01-01T00:59:06  00:00:09  COMPLETED  account_017  assocID_676  ...
# 8  2024-01-01T00:59:06  00:00:09  COMPLETED  account_017  assocID_676  ...
#
#   CPUTimeRAW ReqCPUS AllocCPUS ReqMem MaxRSS ReqNodes  NNodes  NodeList  \
# 4        360      40        40     8G   <NA>        1       1   skl-029
# 5        240      40        40     8G   <NA>        1       1   skl-029
# 6        240      40        40     8G   <NA>        1       1   skl-030
# 7        360      40        40     8G   <NA>        1       1   amr-207
# 8        360      40        40     8G   <NA>        1       1   amr-207
#
#                              ReqTRES                          AllocTRES
# 4  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
# 5  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
# 6  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
# 7  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
# 8  billing=1245,cpu=40,mem=8G,node=1  billing=1245,cpu=40,mem=8G,node=1
#
# [5 rows x 26 columns]

# %%
print(len(slurm_clean))
print(len(batch))
# Out:
# 2110570
# 1528112

# %%
slurm_clean.replace({'A': 0, 'B': 5}, 100)

# %%
filenames = glob('/mnt/scratch/tairaeli/cmse_dat/slurm0_sec_jobs/part**.csv')
with open('/mnt/scratch/tairaeli/cmse_dat/clean_slurm_0sec.csv', 'w') as out:
    for fn in filenames:
        with open(fn) as f:
            out.write(f.read())

# %%
cleanish_slurm = pd.read_csv("/mnt/scratch/tairaeli/cmse_dat/clean_slurm_4.csv",nrows = 100)
cleanish_slurm.head()
# Out:
#    Unnamed: 0     JobID      User      Group               Submit  \
# 0         458  93780800  user_690  group_082  2023-10-09T10:26:30
# 1         461  93780804  user_624  group_154  2023-10-09T10:26:30
# 2        2464  93780808  user_690  group_082  2023-10-09T10:26:30
# 3        2467  93780812  user_624  group_154  2023-10-09T10:26:30
# 4        3316  93780816  user_690  group_082  2023-10-09T10:26:30
#
#                  Start                  End   Elapsed      State      Account  \
# 0  2023-10-09T10:39:37  2023-10-09T10:47:45  00:08:08  COMPLETED  account_066
# 1  2023-10-09T10:30:05  2023-10-09T13:08:09  02:38:04  COMPLETED  account_025
# 2  2023-10-09T10:39:37  2023-10-09T10:47:11  00:07:34  COMPLETED  account_066
# 3  2023-10-09T10:30:05  2023-10-09T14:30:09  04:00:04    TIMEOUT  account_025
# 4  2023-10-09T10:39:47  2023-10-09T11:01:39  00:21:52  COMPLETED  account_066
#
#    ... CPUTimeRAW ReqCPUS AllocCPUS ReqMem MaxRSS ReqNodes NNodes  NodeList  \
# 0  ...       1952       4         4    20G    NaN        1      1   lac-240
# 1  ...       9484       1         1     4G    NaN        1      1   amr-148
# 2  ...       1816       4         4    20G    NaN        1      1   lac-294
# 3  ...      14404       1         1     4G    NaN        1      1   amr-148
# 4  ...       5248       4         4    20G    NaN        1      1   lac-240
#
#                              ReqTRES                          AllocTRES
# 0  billing=3112,cpu=4,mem=20G,node=1  billing=3112,cpu=4,mem=20G,node=1
# 1    billing=622,cpu=1,mem=4G,node=1    billing=622,cpu=1,mem=4G,node=1
# 2  billing=3112,cpu=4,mem=20G,node=1  billing=3112,cpu=4,mem=20G,node=1
# 3    billing=622,cpu=1,mem=4G,node=1    billing=622,cpu=1,mem=4G,node=1
# 4  billing=3112,cpu=4,mem=20G,node=1  billing=3112,cpu=4,mem=20G,node=1
#
# [5 rows x 27 columns]
